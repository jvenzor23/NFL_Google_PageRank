# %%
import numpy as np
import pandas as pd
from itertools import combinations
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sc
import time
import sys

# %% [markdown]
# # Inputting the Data

# %%
# method
betas = np.linspace(0,1,10)
alpha = .4
filesScore = ["Pij_YDS_2009.csv","Pij_YDS_2010.csv",
              "Pij_YDS_2011.csv","Pij_YDS_2012.csv",
              "Pij_YDS_2013.csv","Pij_YDS_2014.csv",
              "Pij_YDS_2015.csv","Pij_YDS_2016.csv",
              "Pij_YDS_2017.csv","Pij_YDS_2018.csv"]

filesPercs = ["2009_win_perc.csv","2010_win_perc.csv","2011_win_perc.csv","2012_win_perc.csv",
             "2013_win_perc.csv","2014_win_perc.csv","2015_win_perc.csv",
             "2016_win_perc.csv","2017_win_perc.csv","2018_win_perc.csv"]
namesCols = ["win_perc_2009","win_perc_2010","win_perc_2011","win_perc_2012",
            "win_perc_2013","win_perc_2014","win_perc_2015",
            "win_perc_2016","win_perc_2017","win_perc_2018"]

# %% [markdown]
# # Function that Takes the Output of the Rankings and Determines The Percent Correct

# %%
def ranking_analyzer(output,names,plot = False, threshold = 0):
    # importing necessary libraries
    from itertools import combinations
    # getting vectors from the data frame
    perc1 = np.array(output[names[0]])
    perc2 = np.array(output[names[1]])
    percscore = np.array(output['score'])
    # getting the combinations
    combs = list(combinations(np.arange(32), 2))
    ncombs = len(combs)
    # initiailizing the vectors
    scorediff = np.zeros(int(ncombs))
    wins1diff = np.zeros(int(ncombs))
    wins2diff = np.zeros(int(ncombs))
    # Computing the values
    for counter, pairs in enumerate(combs):
        scorediff[counter] = percscore[pairs[0]] - percscore[pairs[1]]
        wins1diff[counter] = perc1[pairs[0]] - perc1[pairs[1]]
        wins2diff[counter] = perc2[pairs[0]] - perc2[pairs[1]]

    # putting in a mask for plotting perspective
    mask = wins1diff < 0/16
    scorediff_not_adv = scorediff[mask]
    scorediff_adv = scorediff[np.invert(mask)]

    wins2diff_not_adv = wins2diff[mask]
    wins2diff_adv = wins2diff[np.invert(mask)]
    if plot == True:
        threshmask = scorediff_not_adv > threshold
        scoreplt = scorediff_not_adv[threshmask]
        winsplt = wins2diff_not_adv[threshmask]
        
        correctmask = winsplt > 0
        xc = scoreplt[correctmask]
        yc = winsplt[correctmask]
        xic = scoreplt[np.invert(correctmask)]
        yic = winsplt[np.invert(correctmask)]
        
        plt.figure(figsize=(15,7))
        plt.plot(scorediff_not_adv,wins2diff_not_adv,'ko',label = "Predictions Outside of Threshold")
        plt.plot(xc,yc,'go',label = "Correct Contrary Prediction")
        plt.plot(xic,yic,'ro',label = "Incorrect Contrary Prediction")
        plt.plot([0,1.01*np.max(scorediff)],[0,0],'k-')
        plt.plot([threshold,threshold],[np.min(wins2diff),np.max(wins2diff)],'k-')
        plt.xlabel('Difference in PageRank Score')
        plt.ylabel('Difference in Following Year Winning Percentage')
        plt.legend()
        plt.grid()
        
    
    # Getting the percentage of games where a team with a same or worse record in year N
    # with a better PageRank ended up being better in year N+1
    # Threshold determines amount PageRank needs to be better by
    
    mask = scorediff_not_adv > threshold
    wins2diff_not_adv = wins2diff_not_adv[mask]
    perc_upset = np.sum(wins2diff_not_adv > 0)/len(wins2diff_not_adv)
    n_upset_opps = len(wins2diff_not_adv)
    
    if plot == True:
        plt.title("Correct Percentage of Contrary Predictions: %.3f" %perc_upset)
    
    
    # Getting the total combinations right
    perc_correct_score = sum(wins2diff>0)/len(scorediff)
    perc_correct_wins = (sum(np.logical_and(wins1diff>0,wins2diff>0))+ \
                         sum(np.logical_and(wins1diff<0,wins2diff<0)))/len(wins1diff)
    
    return perc_upset, perc_correct_score,perc_correct_wins,n_upset_opps

# %% [markdown]
# # Function to Take A Pij Matrix and Apply Bagging

# %% [markdown]
# We want this function to take as an inputs:
#
# - $P_{ij}$, the original stochastic matrix.
# - $\alpha$, the teleportation paramter
# - $stats1$, a vector containing the winning percentages of the teams of interest
# - $namesCols$, the names of the win percentage vectors
# - $N$, the number of teams to eliminate at each step (anticipate 1 or 2 will be best)
# - $method$, the method for determining $\nu$, set to 0 (for using weights in each node) by default if not specified.
#
#
# We want this function to output:
#
# - $S$, a matrix of scores where each row is one of the 32 teams, and each column is that teams computed score when ommiting a combination of teams

# %%
def score_bagging(Pij, stats1, namesCols, alpha, N, Nsims = 2500, method = 0):
    # setting a vector to contain each of the 32 team numbers
    teamnum = np.arange(32)
    # Getting the possible combinations of this to use
    combs = list(combinations(teamnum, N))
    ncombs = len(combs)
    # initializing a matrix to store each of these values
    scores = np.zeros((len(teamnum),ncombs))
    # We iterate over all of these combinations, each time computing a final score vector
    for counter, group in enumerate(combs):
        # Adjusting Pij (first deleting the specified rows, then columns)
        Pij_group = np.delete(Pij,group,axis = 0)
        Pij_group = np.delete(Pij_group,group,axis = 1)
        
        # Ensuring Pij has no zero columns
        if len(np.where(Pij_group.sum(axis = 0) == 0)[0]) > 0:
                empty_vect = np.where(Pij_group.sum(axis = 0) == 0)[0]
                for iCnt in range(len(empty_vect)):
                    Pij_group[empty_vect[iCnt],empty_vect[iCnt]] = 1
        
        # -----------Getting the Scores (FROM PREVIOUS CODE)------------------------
        # If we want the teleportation probabilties unifrom,
        # or based on team winning perc
        if method == 0:
            # making the teleporting probabilities uniform
            v = np.ones(len(teamnum)-N)/(len(teamnum)-N)
            v = v[np.newaxis]
            v = v.T
            # Setting alpha
            alpha = alpha
            # Setting eT
            eT = np.ones(len(teamnum)-N)[np.newaxis]   
        else:
            # making the teleporting probabilities proportional to
            # the teams winning percentages
            v = np.array(stats1[namesCols])
            v = np.delete(v, group)
            v = v[np.newaxis]
            v = v.T
            v = v/np.sum(v)
            # Setting alpha
            alpha = alpha
            # Setting eT
            eT = np.ones(len(teamnum)-N)[np.newaxis]
                
        # initializing our first guess
        x0 = np.ones(len(teamnum)-N)/len(teamnum)-N
        x0 = x0[np.newaxis]
        x0 = x0.T
            
        # performing the simulation (so our scores are stored in x0)
        for i in range(Nsims):
            x0 = alpha*np.dot(Pij_group,x0) + (1-alpha)*v

        # ---------------------- (END OF PREVIOUS CODE) ------------------------
        # getting a vector of the values of the teams computed
        kept_vect = np.delete(teamnum,group)
        # Updating the matrix
        scores[kept_vect,counter] = np.squeeze(x0)
    return scores

# %% [markdown]
# # Function to take the Score Matrix as an Input and Output the Final PageRank Vector

# %% [markdown]
# This function takes as inputs:
#
# - $S$, a matrix of scores where each row is one of the 32 teams, and each column is that teams computed score when ommiting a combination of teams
# - $\bar{x}$, the PageRank vector computed for each team over __full__ data set.
# - $\beta$, where the PageRank for each team is computed to be $x_i = (1-\beta)\bar{x}_i + \beta\big(min\{S_{ik}, 1 \leq k \leq {32 \choose N} \text{ for } k \in Z \}\big)$ where $N$ is the number of games removed at a time from the "score_bagging" function.
#
# This function outputs:
#
# - $x$, the vector containing the final PageRank scores for each team.

# %%
def final_score(S, x_bar, beta):
    # getting the minimum vector
    min_vect = np.zeros(32)
    # computing the minimums
    for iCnt in range(len(min_vect)):
        # accounting for winless teams
        if len(S[iCnt,np.nonzero(S[iCnt,])[0]]) == 0:
            min_vect[iCnt] = 0
        else:
            min_vect[iCnt] =  np.min(S[iCnt,np.nonzero(S[iCnt,])[0]])
    # normalizing the minimum vector
    min_vect = min_vect/np.sum(min_vect)
    # computing x
    x = (1-beta)*x_bar + beta*min_vect
    # normalizing x
    x = x/np.sum(x)
    # returning the value
    return np.squeeze(x)

# %% [markdown]
# # Writing a Function to Take Beta As a Parameter and Compute the Percent of Correct Combinations

# %% [markdown]
# This function has the following inputs:
#
# - $\beta$, where the PageRank for each team is computed to be $x_i = (1-\beta)\bar{x}_i + \beta\big(min\{S_{ik}, 1 \leq k \leq {32 \choose N} \text{ for } k \in Z \}\big)$ where $N$ is the number of games removed at a time from the "score_bagging" function.
# - $\alpha$, the teleportation parameter
# - $method$, the method for determining $\nu$, set to 0 (for using weights in each node) by default if not specified.
# - $filesScore$, vector of filenames containing the socres in proper matrix form
# - $filesPercs$, a vector of filenames containing the winning percentages of each team in a given year (used for $\nu$ non-uniform)
# - $namesCols$, the names of the win percentage vectors
# - $N$, the number of teams to omit on each iteration
# - $nSims$, the number of terms to include in the approximation of the true eigenvector
# - $weighted$, a boolean value that is true if the nodes of the graph are to be weighted, and false if they are to be binary.
#
# This function has the following outputs:
#
# - __score_perc_total__, the percentage of combinations of teams correctly predicted by the bagged PageRank method
# - __score_perc_S2__, the standard error of the percentage of combinations of teams correctly predicted by the bagged PageRank method
# - __wins_perc_total__, the percentage of combinations of teams correctly predicted by the standings in the current year
# - __wins_perc_S2__, the standard error of the percentage of combinations of teams correctly predicted by the standings in the current year

# %%
def beta_optimize_perc_combs(betas,alpha,method,filesScore,filesPercs,namesCols, N = 1, nSims = 4000,weighted = True):
    # intializing two vectors to store results
    score_perc_total = np.zeros(len(betas))
    score_perc_S2 = np.zeros(len(betas))
    wins_perc_total = np.zeros(len(betas))
    wins_perc_S2 = np.zeros(len(betas))

    indexer = 0
    
    # iterating over all alphas
    
    # making a waitbar
    toolbar_width = len(betas)
    sys.stdout.write("[%s]" % (" " * toolbar_width))
    sys.stdout.flush()
    sys.stdout.write("\b" * (toolbar_width+1))

    
    for beta_try in betas:
        
        if(alpha >= .8):
            nSims_use = nSims
        else:
            nSims_use = 2500
        
        # initializing the two correlations
        mc_perc_score = 0
        mc_perc_wins = 0
        
        # intializing a vector to get each percentage (for getting a standard deviation)
        sd_vect = np.zeros(len(filesScore) - 1)
        sd_vect_wins = np.zeros(len(filesScore) - 1)
        
        # iterating over all years (we lose a year since we don't have anything 
        # to regress the 2019 data on)
        for year_of_data in np.arange(len(filesScore) - 1):
            
            # reading in the data
            data = pd.read_csv(filesScore[year_of_data],index_col=0)
            stats1 = pd.read_csv(filesPercs[year_of_data],index_col=0)
            stats2 = pd.read_csv(filesPercs[year_of_data + 1],index_col=0)
            # converting to a numpy array
            data2 = np.array(data)
            
            if(weighted == False):
                data2[data2!=0] = 1
            
            # making the Pij matrix
            Pij = data2/data2.sum(axis=0)
            
            # If we want the teleportation probabilties unifrom,
            # or based on team winning perc
            if method == 0:
                # making the teleporting probabilities uniform
                v = np.ones(32)/32
                v = v[np.newaxis]
                v = v.T
                # Setting eT
                eT = np.ones(32)[np.newaxis]   
            else:
                # making the teleporting probabilities proportional to
                # the teams winning percentages
                v = np.array(stats1[namesCols[year_of_data]])
                v = v[np.newaxis]
                v = v.T
                v = v/np.sum(v)
                # Setting eT
                eT = np.ones(32)[np.newaxis]
                
            # initializing our first guess
            x0 = np.ones(32)/32
            x0 = x0[np.newaxis]
            x0 = x0.T
            
            # performing the simulation
            for i in range(nSims_use):
                x0 = alpha*np.dot(Pij,x0) + (1-alpha)*v
            
            x0 = np.squeeze(x0)
                
            # ---------------------- NEW PART OF FUNCTION (ADAPTING x0 to xf) ---------------
            
            scores_mat = score_bagging(Pij, stats1, namesCols[year_of_data], \
                                       alpha, N, Nsims = nSims_use, method = method)
            
            xf = final_score(scores_mat, x0, beta_try)
            
            # -------------------------------------------------------------------------------

            # defining the team names
            team_names = np.array(data.columns.get_values())
            
            # ordering the team's by their score
            mask = np.argsort(np.squeeze(xf))[::-1]
            xf_df = np.squeeze(xf[mask])
            team_names_df = team_names[mask]
            
            # forming a data frame
            teamrank = {'Team': team_names_df, 'score': xf_df, 'wins': 32*16/2*xf_df}
            teamrank_df = pd.DataFrame(data=teamrank)
            
            output = pd.merge(teamrank_df,
                  stats1,
                  left_on = "Team",
                  right_on = "team",
                  how = "inner")

            output = pd.merge(output,
                  stats2,
                  left_on = "Team",
                  right_on = "team",
                  how = "inner")
            
            # Figuring out ranks
            names = [namesCols[year_of_data],namesCols[year_of_data+1]]
            pu, ps, pw, opps = ranking_analyzer(output,names)
            
            # Storing the results
            mc_perc_score += ps
            sd_vect[year_of_data] = ps
            mc_perc_wins += pw
            sd_vect_wins[year_of_data] = pw
            
            
            
        # Updating the percentages
        score_perc_total[indexer] = mc_perc_score/(len(filesScore) - 1)
        score_perc_S2[indexer] = np.std(sd_vect)/np.sqrt(len(filesScore) - 1)
        wins_perc_total[indexer] = mc_perc_wins/(len(filesScore) - 1)
        wins_perc_S2[indexer] = np.std(sd_vect_wins)/np.sqrt(len(filesScore) - 1)
        indexer += 1
        sys.stdout.write("-")
        sys.stdout.flush()
    
        
    sys.stdout.write("\n")
    return score_perc_total,score_perc_S2,wins_perc_total,wins_perc_S2

# %%
def beta_optimize_perc_combs2(betas,alpha,method,filesScore,filesPercs,namesCols, N = 1, nSims = 5000,weighted = True):
    # intializing two vectors to store results
    score_perc_total = np.zeros(len(betas))
    score_perc_S2 = np.zeros(len(betas))
    wins_perc_total = np.zeros(len(betas))
    wins_perc_S2 = np.zeros(len(betas))

    indexer = 0
    
    if(alpha >= .8):
        nSims_use = nSims
    else:
        nSims_use = 5000
    
    # Generating the scores matrix for each year
    # setting a vector to contain each of the 32 team numbers
    teamnum = np.arange(32)
    # Getting the possible combinations of this to use
    combs = list(combinations(teamnum, N))
    ncombs = len(combs)
    scores_mat_for_all = np.zeros((len(filesScore) - 1,32,ncombs))
    
    # iterating over all years (we lose a year since we don't have anything 
    # to regress the 2019 data on)
    
    # making a waitbar
    toolbar_width = len(filesScore) - 1
    sys.stdout.write("[%s]" % (" " * toolbar_width))
    sys.stdout.flush()
    sys.stdout.write("\b" * (toolbar_width+1))
    
    for year_of_data in np.arange(len(filesScore) - 1):
            
        # reading in the data
        data = pd.read_csv(filesScore[year_of_data],index_col=0)
        stats1 = pd.read_csv(filesPercs[year_of_data],index_col=0)
        stats2 = pd.read_csv(filesPercs[year_of_data + 1],index_col=0)
        # converting to a numpy array
        data2 = np.array(data)
            
        if(weighted == False):
            data2[data2!=0] = 1
            
        # making the Pij matrix
        Pij = data2/data2.sum(axis=0)
              
        # ---------------------- NEW PART OF FUNCTION (getting scores) ---------------
            
        scores_mat_for_all[year_of_data] = score_bagging(Pij, stats1, namesCols[year_of_data], \
                                       alpha, N, Nsims = nSims_use, method = method)
        
        sys.stdout.write("-")
        sys.stdout.flush()
        
    sys.stdout.write("\n")    
    # ----------------------- ITERATING OVER BETA ------------
    
    # making a waitbar
    toolbar_width = len(betas)
    sys.stdout.write("[%s]" % (" " * toolbar_width))
    sys.stdout.flush()
    sys.stdout.write("\b" * (toolbar_width+1))

    
    for beta_try in betas:
        
        # initializing the two correlations
        mc_perc_score = 0
        mc_perc_wins = 0
        
        # intializing a vector to get each percentage (for getting a standard deviation)
        sd_vect = np.zeros(len(filesScore) - 1)
        sd_vect_wins = np.zeros(len(filesScore) - 1)
        
        # iterating over all years (we lose a year since we don't have anything 
        # to regress the 2019 data on)
        for year_of_data in np.arange(len(filesScore) - 1):
            
            # reading in the data
            data = pd.read_csv(filesScore[year_of_data],index_col=0)
            stats1 = pd.read_csv(filesPercs[year_of_data],index_col=0)
            stats2 = pd.read_csv(filesPercs[year_of_data + 1],index_col=0)
            
            # converting to a numpy array
            data2 = np.array(data)
            
            if(weighted == False):
                data2[data2!=0] = 1
            
            # making the Pij matrix
            Pij = data2/data2.sum(axis=0)
            
            # If we want the teleportation probabilties unifrom,
            # or based on team winning perc
            if method == 0:
                # making the teleporting probabilities uniform
                v = np.ones(32)/32
                v = v[np.newaxis]
                v = v.T
                # Setting eT
                eT = np.ones(32)[np.newaxis]   
            else:
                # making the teleporting probabilities proportional to
                # the teams winning percentages
                v = np.array(stats1[namesCols[year_of_data]])
                v = v[np.newaxis]
                v = v.T
                v = v/np.sum(v)
                # Setting eT
                eT = np.ones(32)[np.newaxis]
                
            # initializing our first guess
            x0 = np.ones(32)/32
            x0 = x0[np.newaxis]
            x0 = x0.T
            
            # performing the simulation
            for i in range(nSims_use):
                x0 = alpha*np.dot(Pij,x0) + (1-alpha)*v
            
            x0 = np.squeeze(x0)
            
            xf = final_score(scores_mat_for_all[year_of_data], x0, beta_try)
            
            # -------------------------------------------------------------------------------

            # defining the team names
            team_names = np.array(data.columns.get_values())
            
            # ordering the team's by their score
            mask = np.argsort(np.squeeze(xf))[::-1]
            xf_df = np.squeeze(xf[mask])
            team_names_df = team_names[mask]
            
            # forming a data frame
            teamrank = {'Team': team_names_df, 'score': xf_df, 'wins': 32*16/2*xf_df}
            teamrank_df = pd.DataFrame(data=teamrank)
            
            output = pd.merge(teamrank_df,
                  stats1,
                  left_on = "Team",
                  right_on = "team",
                  how = "inner")

            output = pd.merge(output,
                  stats2,
                  left_on = "Team",
                  right_on = "team",
                  how = "inner")
            
            # Figuring out ranks
            names = [namesCols[year_of_data],namesCols[year_of_data+1]]
            pu, ps, pw, opps = ranking_analyzer(output,names)
            
            # Storing the results
            mc_perc_score += ps
            sd_vect[year_of_data] = ps
            mc_perc_wins += pw
            sd_vect_wins[year_of_data] = pw
            
            
            
        # Updating the percentages
        score_perc_total[indexer] = mc_perc_score/(len(filesScore) - 1)
        score_perc_S2[indexer] = np.std(sd_vect)/np.sqrt(len(filesScore) - 1)
        wins_perc_total[indexer] = mc_perc_wins/(len(filesScore) - 1)
        wins_perc_S2[indexer] = np.std(sd_vect_wins)/np.sqrt(len(filesScore) - 1)
        indexer += 1
        sys.stdout.write("-")
        sys.stdout.flush()
    
        
    sys.stdout.write("\n")
    return score_perc_total,score_perc_S2,wins_perc_total,wins_perc_S2

# %% [markdown]
# # Running it For $\alpha = 0.4$

# %%
alpha = 0.4

# %%
score_perc0,score_perc_S20,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc1,score_perc_S21,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc2,score_perc_S22,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_perc3,score_perc_S23,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc0,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc1,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc2,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc3,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %%
print("Advantage over non-bagged for uniform, unweighted: %.3f percent" %(100*(np.max(score_perc2)- score_perc2[0])))
# Out:
# Advantage over non-bagged for uniform, unweighted: 0.269 percent

# %%
print("Best Accuracy: %.3f percent" %(100*(np.max(score_perc2))))
# Out:
# Best Accuracy: 57.527 percent

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc_S20,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S21,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S22,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S23,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winssd,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Running it For $\alpha = 0.1$

# %%
alpha = 0.1

# %%
score_perc4,score_perc_S24,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc5,score_perc_S25,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          -----
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: invalid value encountered in long_scalars
# -----

# %%
score_perc7,score_perc_S27,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_perc6,score_perc_S26,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          --
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: invalid value encountered in long_scalars
# --------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc4,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc5,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc7,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc6,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %%
print("Advantage over non-bagged for uniform, unweighted: %.3f percent" %(100*(np.max(score_perc7)- score_perc7[0])))
# Out:
# Advantage over non-bagged for uniform, unweighted: 0.448 percent

# %%
print("Best Accuracy: %.3f percent" %(100*(np.max(score_perc7))))
# Out:
# Best Accuracy: 57.885 percent

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc_S24,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S25,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S27,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S26,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winssd,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Running it For $\alpha = 0.75$

# %%
alpha = .75

# %%
score_perc8,score_perc_S28,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc9,score_perc_S29,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc10,score_perc_S10,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_perc11,score_perc_S11,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols,weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc8,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc9,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc10,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc11,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %%
print("Advantage over non-bagged for uniform, unweighted: %.3f percent" %(100*(np.max(score_perc10)- score_perc10[0])))
# Out:
# Advantage over non-bagged for uniform, unweighted: 0.650 percent

# %%
print("Best Accuracy: %.3f percent" %(100*(np.max(score_perc10))))
# Out:
# Best Accuracy: 57.370 percent

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc_S28,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S29,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S10,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S11,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winssd,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Running it For $\alpha = 0.9$

# %%
alpha = 0.9

# %%
score_perc13,score_perc_S213,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc12,score_perc_S212,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols)
# Out:
# [        ---------
# [          ----------

# %%
score_perc14,score_perc_S214,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,0,filesScore,filesPercs,namesCols,
                                                                       weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_perc15,score_perc_S215,winsperc,winssd = beta_optimize_perc_combs2(betas,alpha,1,filesScore,filesPercs,namesCols,
                                                                       weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc13,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc12,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc14,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc15,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc_S213,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S212,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S214,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,score_perc_S215,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.plot(betas,winssd,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Putting it All on One Plot

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_perc7,'b-',label = r'$\alpha$ = 0.1', color = "darkorange")
plt.plot(betas,score_perc2,'r-',label = r'$\alpha$ = 0.4', color = "green")
plt.plot(betas,score_perc10,'r-',label = r'$\alpha$ = 0.75',color = "navy")
plt.plot(betas,score_perc14,'r-',label = r'$\alpha$ = 0.9',color = "black")
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 1$')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Running it with $N = 2$

# %% [markdown]
# ## alpha = 0.1

# %%
alpha = 0.1

# %%
score_percn21,score_percn2_S21,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn22,score_percn2_S22,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
print("Best Accuracy: %.3f percent" %(100*(np.max(score_percn22))))
# Out:
# Best Accuracy: 57.997 percent

# %%
score_percn23,score_percn2_S23,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: invalid value encountered in long_scalars
# ------

# %%
score_percn24,score_percn2_S24,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          --
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: invalid value encountered in long_scalars
# --------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn21,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn22,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn23,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn24,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## alpha = 0.4

# %%
alpha = 0.4

# %%
score_percn25,score_percn2_S25,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn26,score_percn2_S26,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_percn27,score_percn2_S27,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn28,score_percn2_S28,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn25,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn26,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn27,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn28,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn2_S25,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn2_S26,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn2_S27,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn2_S28,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winssd,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## alpha = 0.75

# %%
alpha = 0.75

# %%
score_percn29,score_percn2_S29,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn210,score_percn2_S210,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_percn211,score_percn2_S211,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn212,score_percn2_S212,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn29,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn210,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn211,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn212,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## alpha = 0.25

# %%
alpha = 0.25

# %%
score_percn213,score_percn2_S213,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn214,score_percn2_S214,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_percn215,score_percn2_S215,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn216,score_percn2_S216,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn213,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn214,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn215,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn216,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## alpha = 0.50

# %%
alpha = 0.50

# %%
score_percn217,score_percn2_S217,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn218,score_percn2_S218,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,0,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
score_percn219,score_percn2_S219,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2)
# Out:
# [        ---------
# [          ----------

# %%
score_percn220,score_percn2_S220,winsperc,winssd = beta_optimize_perc_combs2(betas, \
                                alpha,1,filesScore,filesPercs,namesCols, N = 2, weighted = False)
# Out:
# [        ---------
# [          ----------

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn217,'b-',label = r'Year $N$ PageRank Score with uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn218,'b--',label = r'Year $N$ PageRank Score with uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,score_percn219,'r-',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and weighted $\nu$, $N = 2$')
plt.plot(betas,score_percn220,'r--',label = r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r"$\alpha$ = %.2f" %alpha)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Putting it All on One Plot

# %%
plt.figure(figsize=(15,7))
plt.plot(betas,score_percn22,'b-',label = r'$\alpha$ = 0.1', color = "crimson",linewidth = 5)
plt.plot(betas,score_percn214,'r-',label = r'$\alpha$ = 0.25', color = "violet")
plt.plot(betas,score_percn26,'r-',label = r'$\alpha$ = 0.4',color = "black")
plt.plot(betas,score_percn218,'r-',label = r'$\alpha$ = 0.5',color = "slateblue")
plt.plot(betas,score_percn210,'r-',label = r'$\alpha$ = 0.75',color = "darkblue")


plt.plot(betas,winsperc,'k--',label = r'Year $N$ Wins')
plt.xlabel(r'Weight of Worst Scenario ($\beta$)')
plt.ylabel("Percentage of Pairs Correctly Predicted")
plt.title(r'Year $N$ PageRank Score with non-uniform $\gamma$ and unweighted $\nu$, $N = 2$')
plt.legend()
plt.grid()
plt.show()
